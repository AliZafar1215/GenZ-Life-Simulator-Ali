# %% [markdown]
# -PROGRAMMING FOR ARTIFICIAL INTELLIGENCE
#
# -ASSIGNMENT 1
#
# -NAME: ALI ZAFAR
#
# -ENROLLMENT NUMBER: 01-136242-005

# %%
# --- Profile Setup ---
print("Hello! 👋 I am your chatbot friend.")
name = input("What is your name? ")
age = input("How old are you? ")

print("Nice to meet you,", name, "! 🤖")
print("You can talk to me. Say hi, how are you, test, or bye.\n")

# %%
# --- Dictionary Used for Chatbot Replies ---
responses = {
    "hi": "Hey bestie! 😄 How are you?",
    "how are you": "I am good! Just happy to talk to you. 😊",
    "tell me a joke": "Why did the chicken cross the road? To get to the other side, duh! 😂",
    "bye": "Okay bye! See you soon 👋",
    "test": "Yay! Let’s do a fun personality test 🧠"
}

# %%
# --- Personality Test Function ---
def personality_test():
    print("\n🧠 Let's start the test!")
    funny = 0
    calm = 0
    focused = 0

    print("\n1. It’s the weekend. What will you do?")
    print("a) Watch funny videos\nb) Relax\nc) Plan your week")
    ans = input("Your choice: ").lower()
    if ans == "a":
        funny += 1
    elif ans == "b":
        calm += 1
    else:
        focused += 1

    print("\n2. Your friend cancels a plan. You will...")
    print("a) Laugh\nb) Stay calm\nc) Work on something else")
    ans = input("Your choice: ").lower()
    if ans == "a":
        funny += 1
    elif ans == "b":
        calm += 1
    else:
        focused += 1

    print("\n3. You see a funny meme. You...")
    print("a) Share it\nb) Smile quietly\nc) Ignore it")
    ans = input("Your choice: ").lower()
    if ans == "a":
        funny += 1
    elif ans == "b":
        calm += 1
    else:
        focused += 1

    print("\n4. You have an assignment due today.")
    print("a) Make a joke about it\nb) Do it slowly\nc) Finish it quickly")
    ans = input("Your choice: ").lower()
    if ans == "a":
        funny += 1
    elif ans == "b":
        calm += 1
    else:
        focused += 1

    print("\n5. You are at a party and music stops.")
    print("a) Make a joke\nb) Sit quietly\nc) Try to fix it")
    ans = input("Your choice: ").lower()
    if ans == "a":
        funny += 1
    elif ans == "b":
        calm += 1
    else:
        focused += 1

# %%
    # --- Personality Result ---
    print("\n✨ Your Personality Result ✨")
    if funny > calm and funny > focused:
        print("You are FUNNY! 😂 You make people smile.")
    elif calm > funny and calm > focused:
        print("You are CALM! 😌 You stay cool in every situation.")
    else:
        print("You are FOCUSED! 🎯 You always finish your work on time.")

# %%
# --- Chat Loop (Keeps the Chat Running) ---
while True:
    user_input = input("\nYou: ").lower()

    if user_input == "bye":
        print("Chatbot:", responses["bye"])
        break
    elif user_input == "test":
        print("Chatbot:", responses["test"])
        personality_test()
    elif user_input in responses:
        print("Chatbot:", responses[user_input])
    else:
        print("Chatbot: I don’t understand that 😅")
